# %% [markdown]
# # Exercise 1.4 Bonus

# %% [markdown]
# ## 01. Imports/Libraries

# %%
# Import libraries

import pandas as pd
import time
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
import matplotlib.pyplot as plt
import os
import logging
import requests
from bs4 import BeautifulSoup

# %%
## Setup chrome options

chrome_options = Options()
chrome_options.add_argument("--headless") # Ensure GUI is off
chrome_options.add_argument("--no-sandbox")

# %%
## Install Chrome driver manager, auto-downloads the correct and recent version of chromedrivers.

service = Service(executable_path=ChromeDriverManager().install())

# %%
driver = webdriver.Chrome(service = service)

# %% [markdown]
# ## 02. Country List Scrape

# %%
# Get the page's contents

page_url = "https://simple.wikipedia.org/wiki/List_of_countries"
driver.get(page_url)

# %%
# Check how many div-col blocks were found
country_elems = driver.find_elements(By.CLASS_NAME, "div-col")
print(len(country_elems))
# Out:
# 0

# %%
# Extract and split the text
list_countries = country_elems[0].text.split("\n")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[18], line 2
#       1 # Extract and split the text
# ----> 2 list_countries = country_elems[0].text.split("\n")
#
# IndexError: list index out of range
